# %% [markdown]
# - loss = , validation

# %%
for i in range(47):
    for j in range(1,9):
        # !taskset -c 10-19 python3.6 experiment.py -d {i} -l 1 -mi {j} -g 1
# Out:
# device: args.cuda:1, dataset name : 1_ALOI, model: mlp, sampling: none, minor_number : 1, loss: msfe
# 100%|█████████████████████████████████████████| 150/150 [01:12<00:00,  2.07it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:08<00:00,  2.19it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:08<00:00,  2.19it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:09<00:00,  2.17it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:09<00:00,  2.16it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:09<00:00,  2.17it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:08<00:00,  2.19it/s]
# 1_ALOI_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [01:08<00:00,  2.20it/s]
# 1_ALOI_mlp_none_msfe
# ...

# %%
for j in range(1,9):
    # !taskset -c 0-9 python3.6 experiment.py -d 1 -l 1 -mi {j} -g 0
# Out:
# device: args.cuda:0, dataset name : 2_annthyroid, model: mlp, sampling: none, minor_number : 1, loss: msfe
# 100%|█████████████████████████████████████████| 150/150 [00:26<00:00,  5.75it/s]
# Figure(640x480)
# 2_annthyroid_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [00:25<00:00,  5.88it/s]
# Figure(640x480)
# 2_annthyroid_mlp_none_msfe
# 50.6(2.2)
# /home/ppleeqq/IMvsAD/save_result/2023-11-15/2_annthyroid_msfe_none_minor_1.csv 으로 저장되었습니다.
# Finish!
# device: args.cuda:0, dataset name : 2_annthyroid, model: mlp, sampling: none, minor_number : 3, loss: msfe
# 100%|█████████████████████████████████████████| 150/150 [00:28<00:00,  5.20it/s]
# Figure(640x480)
# 2_annthyroid_mlp_none_msfe
# 100%|█████████████████████████████████████████| 150/150 [00:27<00:00,  5.49it/s]
# Figure(640x480)
# 2_annthyroid_mlp_none_msfe
# 51.5(0.4)
# /home/ppleeqq/IMvsAD/save_result/2023-11-15/2_annthyroid_msfe_none_minor_3.csv 으로 저장되었습니다.
# Finish!
# ...

# %%
# !taskset -c 0-9 python3.6 experiment.py -d 1 -l 1 -mi 0 -g 0 -e 50 -t True
# Out:
# device: args.cuda:0, dataset name : 2_annthyroid, model: mlp, sampling: none, minor_number : none, loss: msfe
#   0%|                                                    | 0/50 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
#  98%|██████████████████████████████████████████▏| 49/50 [00:07<00:00,  6.38it/s]
